# %%
import pandas as pd
import numpy as np

# %%
#df1 = pd.read_csv("/kaggle/input/optimize-any-solution-with-group-theory-approach/optimized_top.csv")
df1 = pd.read_csv("/kaggle/input/notebook80fe8c6045/submission.csv")

# %%
df1.to_csv("submission.csv", index=False)
